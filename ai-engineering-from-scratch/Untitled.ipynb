# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
data = np.random.randn(1000)
data.mean(), data.std()
# Out:
# (np.float64(-0.015098626857601091), np.float64(1.0081792698150054))

# %%
import sys
print(sys.executable)
# Out:
# /home/rocky/AIfromSCRATCH/makeAI-fromSCRATCH/ai-engineering-from-scratch/.venv/bin/python3

# %%
import sys
# !uv pip install --python {sys.executable} pandas matplotlib numpy
# Out:
# Resolved 12 packages in 1.08s
# Prepared 1 package in 931ms
# Installed 1 package in 657ms
#  + pandas==3.0.3

# %%
# %%time
model.fit(X_train, y_train, epochs=10)
# Out:
# CPU times: user 14 μs, sys: 1 μs, total: 15 μs
# Wall time: 25.7 μs
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 get_ipython().run_cell_magic('time', '', 'model.fit(X_train, y_train, epochs=10)\n')
#
# File <timed eval>:1
# ----> 1 'Could not get source, probably due dynamically evaluated source code.'
#
# NameError: name 'model' is not defined

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt

# %%
# %timeit np.random.randn(10000)

# %% [markdown]
# $E = mc^2$

# %%
# !pip install scikit-learn

# %%
import pandas as pd

df = pd.DataFrame({
    "model": ["Linear", "Random Forest", "Neural Net"],
    "accuracy": [0.72, 0.89, 0.94],
    "training_time": [0.1, 2.3, 45.6]
})
df

# %%
plt.figure(figsize=(8, 4))
plt.plot([1, 2, 3, 4], [1, 4, 2, 3])
plt.title("Inline Plot")
plt.show()

# %%
# %env CUDA_VISIBLE_DEVICES

# %%
from IPython.display import Image, display
display(Image(filename="architecture.png"))
